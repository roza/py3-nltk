# %%
from nltk.book import *
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1:
#  Moby Dick by Herman Melville 1851
# text2:
#  Sense and Sensibility by Jane Austen 1811
# text3:
#  The Book of Genesis
# text4:
#  Inaugural Address Corpus
# text5:
#  Chat Corpus
# text6:
#  Monty Python and the Holy Grail
# text7:
#  Wall Street Journal
# text8: Personals Corpus
# text9:
#  The Man Who Was Thursday by G . K . Chesterton 1908

# %%
# Vocabulaire = ensemble des mots distincts du corpus
# on l'obtient avec la commande sorted(set(text))
# on filtre ensuite pour limiter aux chaines alphabétiques

[x for x in sorted(set(text1)) if x.isalpha()]
# Out:
# ['A',
#  'ABOUT',
#  'ACCOUNT',
#  'ADDITIONAL',
#  'ADVANCING',
#  'ADVENTURES',
#  'AFFGHANISTAN',
#  'AFRICA',
#  'AFTER',
#  'AGAINST',
#  'AHAB',
#  'ALFRED',
#  'ALGERINE',
#  'ALIVE',
#  'ALL',
#  'ALONE',
#  'AM',
#  'AMERICA',
#  'AMONG',
#  'ANCHORS',
#  'AND',
#  'ANGLO',
#  'ANIMAL',
#  'ANNALS',
#  'ANNUS',
#  'ANOTHER',
#  'ANY',
#  'APOLOGY',
#  'APPLICATION',
#  'APPROACHING',
#  'ARCTIC',
#  'ARE',
#  'AROUND',
#  'AS',
#  'ASCENDING',
#  'ASIA',
#  'ASIDE',
#  'ASPECT',
#  'AT',
#  'ATTACK',
#  'ATTACKED',
#  'ATTITUDES',
#  'AUGUST',
#  'AUTHOR',
#  'AZORE',
#  'Abashed',
#  'Abednego',
#  'Abel',
#  'Abjectus',
#  'Aboard',
#  'Abominable',
#  'About',
#  'Above',
#  'Abraham',
#  'Academy',
#  'Accessory',
#  'According',
#  'Accordingly',
#  'Accursed',
#  'Achilles',
#  'Actium',
#  'Acushnet',
#  'Adam',
#  'Adieu',
#  'Adios',
#  'Admiral',
#  'Admirals',
#  'Advance',
#  'Advancement',
#  'Adventures',
#  'Adverse',
#  'Advocate',
#  'Affected',
# ...

# %%
# Diversité = 1 si aucune répétion dans le texte
# Plus grand sinon
def diversite (text):
    return len(text)/len(set(text))

# %%
# Diversité dans Mobydick
diversite(text1)
# Out:
# 13.502044830977896

# %%
#Diversité dans la Genèse
diversite(text3)
# Out:
# 16.050197203298673

# %%
diversite(text5)
# Out:
# 7.420046158918563

# %%
diversite(text7)
# Out:
# 8.113797549967762

# %%
# diversite dans les discours inauguraux des présidents
diversite(text4)
# Out:
# 14.941049825712529

# %%
text4.dispersion_plot(["God","citizens", "democracy", "freedom", "duties", "America","love","holidays"])

# %%
text4.generate()
# Out:
# Building ngram index...
# Fellow - Citizens , there are people who support a party , the
# Government and to pay that price . It is inspiring , too , the
# safeguard of the government and most economical mode in which the
# highest interests of the Government at all of impertinence . If the
# educated and influential classes in a permanent provision should be
# taken into account and the pursuit of happiness . If parties in
# personal actions the people of America ' s wonders to raise the values
# of faith , to diminish it . We were in the service of humanity .

# %%
def tailleVocabulaire(text):
    return len(sorted(set(text)))

# %%
# vocabulaire bien fourni pour Mobydick
tailleVocabulaire(text1)
# Out:
# 19317

# %%
tailleVocabulaire(text2)
# Out:
# 6833

# %%
tailleVocabulaire(text5)
# Out:
# 6066

# %%
# la première occurrence de 'moon' dans text1
text1.index('moon')
# Out:
# 24712

# %%
# comptage des occurences
text1.count('moon')
# Out:
# 9

# %%
fdist1 = FreqDist(text1)
Vocabulaire = fdist1.keys()

# %%
fdist1.plot (30, cumulative=True)

# %%
[x for x in fdist1.hapaxes() if x.isalpha()]
# Out:
# ['ABOUT',
#  'ADDITIONAL',
#  'ADVENTURES',
#  'AFFGHANISTAN',
#  'AFRICA',
#  'AFTER',
#  'AGAINST',
#  'ALFRED',
#  'ALGERINE',
#  'ALIVE',
#  'AMERICA',
#  'AMONG',
#  'ANCHORS',
#  'ANGLO',
#  'ANIMAL',
#  'ANNALS',
#  'ANNUS',
#  'ANOTHER',
#  'ANY',
#  'APOLOGY',
#  'APPLICATION',
#  'APPROACHING',
#  'ARCTIC',
#  'ARE',
#  'AROUND',
#  'AS',
#  'ASCENDING',
#  'ASIA',
#  'ASPECT',
#  'ATTACK',
#  'ATTACKED',
#  'ATTITUDES',
#  'AUGUST',
#  'AUTHOR',
#  'Abashed',
#  'Abednego',
#  'Abel',
#  'Abjectus',
#  'Aboard',
#  'Abominable',
#  'Academy',
#  'Accessory',
#  'Accursed',
#  'Achilles',
#  'Actium',
#  'Acushnet',
#  'Adios',
#  'Admirals',
#  'Advance',
#  'Advancement',
#  'Adventures',
#  'Adverse',
#  'Advocate',
#  'Affected',
#  'Affidavit',
#  'Affrighted',
#  'Africans',
#  'Aft',
#  'Afterwards',
#  'Against',
#  'Agassiz',
#  'Ages',
#  'Ahabs',
#  'Ahaz',
#  'Akin',
#  'Aladdin',
#  'Alarmed',
#  'Albemarle',
#  'Albert',
#  'Albicore',
#  'Aldrovandi',
# ...

# %%
tokens = nltk.word_tokenize()
